# %% [markdown]
# # Dashboard Deep Dive Notebook (All Dashboards)
#
# This notebook is your detailed study and presentation guide for every dashboard surface currently in scope.

# %%
from pathlib import Path
try:
    from IPython.display import SVG, Markdown, display
except Exception:
    def SVG(content):
        return content

    def Markdown(content):
        return content

    def display(content):
        print(content)

NOTEBOOK_DIR_CANDIDATES = [
    Path.cwd(),
    Path.cwd() / "docs" / "client-handoff" / "notebooks",
    Path("docs/client-handoff/notebooks"),
]
NOTEBOOK_DIR = next(
    (
        candidate.resolve()
        for candidate in NOTEBOOK_DIR_CANDIDATES
        if candidate.exists() and (candidate / "../assets").resolve().exists()
    ),
    Path.cwd().resolve(),
)


def resolve_notebook_path(path):
    target = Path(path)
    if target.is_absolute():
        return target

    return (NOTEBOOK_DIR / target).resolve()


def notebook_markdown_path(path):
    return Path(path).as_posix()

def show_img(path, label='Image'):
    resolved = resolve_notebook_path(path)
    if resolved.exists():
        display(Markdown(f"![{label}]({notebook_markdown_path(path)})"))
    else:
        display(Markdown(f"**Missing {label}**\n\nExpected path: `{path}`"))

def md_list(items):
    return "\n".join([f"- {i}" for i in items])

def section_block(name, purpose, users, inputs, formulas, actions, good, risk, value, screenshot):
    txt = f"""### {name}

**Purpose**  
{purpose}

**Primary Users**  
{users}

**Inputs / Dependencies**  
{md_list(inputs)}

**Logic / Formula Notes**  
{md_list(formulas)}

**Operator Actions**  
{md_list(actions)}

**Healthy Signal**  
{good}

**Risk Signal**  
{risk}

**Client Value Story**  
{value}

**Screenshot Target**  
`{screenshot}`
"""
    display(Markdown(txt))

# %% [markdown]
# ## Visual Map

# %%
show_img("../assets/dashboard-layout-map.svg", "Dashboard layout map")
# Out:
# ![Dashboard layout map](../assets/dashboard-layout-map.svg)

# %% [markdown]
# ## Capture Checklist
#
# Before a client call, capture and save these screenshots in `../assets/screenshots/`:
#
# - `dashboard-widget-summary.png`
# - `overview-control-row.png`
# - `overview-origin-snapshot.png`
# - `overview-today-operations.png`
# - `overview-upcoming-arrivals.png`
# - `overview-action-board.png`
# - `overview-kpi-tiles.png`
# - `overview-pipeline-snapshot.png`
# - `overview-data-quality-radar.png`
# - `overview-breakdowns.png`

# %%
dashboard_sections = [
  {
    "name": "WP Dashboard Widget: Chama Ops Summary",
    "purpose": "Quick at-a-glance context directly on the default WordPress dashboard.",
    "users": "Owner, manager, or operator logging in for a fast check.",
    "inputs": [
      "Published guest/stay counts",
      "Most recent guest records",
      "Most recent stay records"
    ],
    "formulas": [
      "No derived math; direct post counts and latest lists."
    ],
    "actions": [
      "Open recent guest/stay records from links."
    ],
    "good": "Counts and recent links reflect expected activity.",
    "risk": "No records or stale recency indicates process adoption gap.",
    "value": "Shows immediate software utility without leaving dashboard home.",
    "screenshot": "../assets/screenshots/dashboard-widget-summary.png"
  },
  {
    "name": "Overview: Control and Action Row",
    "purpose": "Centralized controls for scenario loading, data lifecycle actions, and exports.",
    "users": "Demo lead, operator, owner.",
    "inputs": [
      "Seed/clear/promote actions",
      "CSV export actions",
      "Queue shortcuts"
    ],
    "formulas": [
      "Action links are nonce-protected admin-post actions."
    ],
    "actions": [
      "Generate/Regenerate demo scenarios",
      "Keep sample records as persistent",
      "Export guests/stays CSV"
    ],
    "good": "Operators can reset or preserve demo state intentionally.",
    "risk": "Regenerate without preserve can wipe edited sample records.",
    "value": "Strong demo control translates to stronger sales and onboarding confidence.",
    "screenshot": "../assets/screenshots/overview-control-row.png"
  },
  {
    "name": "Overview: Record Origin Snapshot",
    "purpose": "Visual separation of sample vs persistent records.",
    "users": "Operator, implementation lead.",
    "inputs": [
      "Sample record marker meta",
      "Current guest/stay totals"
    ],
    "formulas": [
      "Persistent count = total count - sample count"
    ],
    "actions": [
      "Open sample-only and persistent-only queues."
    ],
    "good": "Persistent counts rise after promote action.",
    "risk": "High sample ratio in late-stage rollout indicates migration not completed.",
    "value": "Prevents data trust confusion and supports safer demos.",
    "screenshot": "../assets/screenshots/overview-origin-snapshot.png"
  },
  {
    "name": "Overview: Today Operations Board",
    "purpose": "Day-of command surface for arrivals, departures, and readiness risk signals.",
    "users": "Front desk, operations manager.",
    "inputs": [
      "Stay status",
      "Check-in/check-out dates",
      "Guest contact fields"
    ],
    "formulas": [
      "In-house = check_in <= today < check_out and status in booked/checked_in",
      "Contact ready (48h) = (booked arrivals in 48h - contact gaps) / booked arrivals in 48h"
    ],
    "actions": [
      "Open arrivals/departures queues",
      "Open contact-gap queue",
      "Open 48h arrivals queue"
    ],
    "good": "High contact-ready rate and low overdue arrivals.",
    "risk": "High contact gaps or overdue arrivals before peak check-in windows.",
    "value": "Directly protects guest experience and front-desk calm.",
    "screenshot": "../assets/screenshots/overview-today-operations.png"
  },
  {
    "name": "Overview: Upcoming Arrivals (14 days)",
    "purpose": "Forward-looking readiness cards per upcoming booked stay.",
    "users": "Operations planning and owner review.",
    "inputs": [
      "Booked stays",
      "Guest linkage",
      "Dates",
      "Nights",
      "Revenue"
    ],
    "formulas": [
      "Readiness = no missing guest/date/nights/revenue issues"
    ],
    "actions": [
      "Open stay or guest directly",
      "Open booked and quality queues"
    ],
    "good": "Most cards show Ready with no issues.",
    "risk": "Issue backlog close to arrival dates.",
    "value": "Shifts operations from reactive to proactive.",
    "screenshot": "../assets/screenshots/overview-upcoming-arrivals.png"
  },
  {
    "name": "Overview: Action Board",
    "purpose": "Prioritized recommendations generated from pipeline, quality, and readiness metrics.",
    "users": "Owner and operator lead.",
    "inputs": [
      "Pipeline metrics",
      "Data quality counts",
      "Today-ops contact readiness"
    ],
    "formulas": [
      "Rule-based recommendation thresholds; top three recommendations shown."
    ],
    "actions": [
      "Click recommended queue to resolve top risks first."
    ],
    "good": "Recommendations become On Track style when risk is low.",
    "risk": "Repeated high-priority recommendations indicate unresolved workflow bottleneck.",
    "value": "Converts metrics into clear next actions without analytics expertise.",
    "screenshot": "../assets/screenshots/overview-action-board.png"
  },
  {
    "name": "Overview: KPI Tiles",
    "purpose": "Quick business health snapshot (volume + value).",
    "users": "Owner, manager.",
    "inputs": [
      "Guest/stay totals",
      "Nights",
      "Revenue data"
    ],
    "formulas": [
      "Booked/Active Nights aggregated across booked, checked-in, checked-out",
      "Average Revenue/Stay and Revenue/Night from valid values only"
    ],
    "actions": [
      "Scan trend direction before diving into detailed queues."
    ],
    "good": "Nights and average values trend predictably with occupancy.",
    "risk": "N/A values suggest missing revenue or invalid date data.",
    "value": "Gives leadership confidence in operating and financial hygiene.",
    "screenshot": "../assets/screenshots/overview-kpi-tiles.png"
  },
  {
    "name": "Overview: Pipeline Snapshot",
    "purpose": "Booking lifecycle quality view (conversion/cancellation/lead backlog).",
    "users": "Owner and marketing/ops coordination.",
    "inputs": [
      "Stay status summary"
    ],
    "formulas": [
      "Booked-or-later rate = (booked + checked_in + checked_out) / total mix",
      "Lead backlog rate = leads / total mix",
      "Cancellation rate = cancelled / total mix"
    ],
    "actions": [
      "Jump to booked/lead/cancelled queues for remediation."
    ],
    "good": "Booked-or-later healthy, lead backlog and cancellations controlled.",
    "risk": "High lead backlog or cancellations indicate conversion/policy problems.",
    "value": "Connects operational system to growth and retention outcomes.",
    "screenshot": "../assets/screenshots/overview-pipeline-snapshot.png"
  },
  {
    "name": "Overview: Data Quality Radar",
    "purpose": "Single source for missing data that harms service and reporting.",
    "users": "Operator and QA owner.",
    "inputs": [
      "Guest and stay meta completeness checks"
    ],
    "formulas": [
      "Issue totals grouped by specific quality queue categories."
    ],
    "actions": [
      "Open filtered list for each issue class."
    ],
    "good": "Issue totals trend down over time.",
    "risk": "Persistent issue counts create hidden operational debt.",
    "value": "Prevents silent data drift and protects dashboard trust.",
    "screenshot": "../assets/screenshots/overview-data-quality-radar.png"
  },
  {
    "name": "Overview: Stay Status + Guest Source Breakdowns",
    "purpose": "Current distribution context for operational and acquisition analysis.",
    "users": "Owner, manager.",
    "inputs": [
      "Stay statuses",
      "Guest marketing source"
    ],
    "formulas": [
      "Count-based distributions from current records."
    ],
    "actions": [
      "Compare source mix and status mix against expectations."
    ],
    "good": "Mix aligns with business strategy and seasonality.",
    "risk": "Unexpected source or status skew may indicate workflow breakage.",
    "value": "Adds planning context without requiring external BI tooling.",
    "screenshot": "../assets/screenshots/overview-breakdowns.png"
  }
]

# %%
for sec in dashboard_sections:
    section_block(
        sec["name"], sec["purpose"], sec["users"], sec["inputs"], sec["formulas"],
        sec["actions"], sec["good"], sec["risk"], sec["value"], sec["screenshot"]
    )
    show_img(sec["screenshot"], sec["name"])
# Out:
# ### WP Dashboard Widget: Chama Ops Summary
#
# **Purpose**
# Quick at-a-glance context directly on the default WordPress dashboard.
#
# **Primary Users**
# Owner, manager, or operator logging in for a fast check.
#
# **Inputs / Dependencies**
# - Published guest/stay counts
# - Most recent guest records
# - Most recent stay records
#
# **Logic / Formula Notes**
# - No derived math; direct post counts and latest lists.
#
# **Operator Actions**
# - Open recent guest/stay records from links.
#
# **Healthy Signal**
# Counts and recent links reflect expected activity.
#
# **Risk Signal**
# No records or stale recency indicates process adoption gap.
#
# **Client Value Story**
# Shows immediate software utility without leaving dashboard home.
#
# **Screenshot Target**
# `../assets/screenshots/dashboard-widget-summary.png`
# **Missing WP Dashboard Widget: Chama Ops Summary**
#
# Expected path: `../assets/screenshots/dashboard-widget-summary.png`
# ### Overview: Control and Action Row
#
# ...

# %% [markdown]
# ## Study Drill
#
# For each section above, practice answering:
#
# 1. What decision does this section support?
# 2. What data dependency could make it wrong?
# 3. What exact click should the client take next?
